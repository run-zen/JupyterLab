# %%
import pandas as pd
from datetime import timedelta

# %%
xl_file = pd.ExcelFile('KPMG_RawData.xlsx')

# %%
transaction = pd.read_excel(xl_file, sheet_name = "Transactions")

# %%
transaction.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# 0       71.49          53.62                  41245.0
# 1     2091.47         388.92                  41701.0
# 2     1793.43         248.82                  36361.0
# 3     1198.46         381.10                  36145.0
# 4     1765.30         709.48                  42226.0

# %%
transaction["Profit"] = transaction["list_price"] - transaction["standard_cost"]
display(transaction.head())
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date   Profit
# 0       71.49          53.62                  41245.0    17.87
# 1     2091.47         388.92                  41701.0  1702.55
# 2     1793.43         248.82                  36361.0  1544.61
# 3     1198.46         381.10                  36145.0   817.36
# 4     1765.30         709.48                  42226.0  1055.82

# %%
transaction["transaction_date"] = pd.to_datetime(transaction["transaction_date"])

# %%
snapshot_date = transaction["transaction_date"].max() + timedelta(days = 1)
print(snapshot_date)
# Out:
# 2017-12-31 00:00:00

# %%
data_process = transaction.groupby(['customer_id']).agg({'transaction_date': lambda x: (snapshot_date - x.max()).days,
                                                        'transaction_id': 'count',
                                                        'Profit': 'sum'})
display(data_process.head())
# Out:
#              transaction_date  transaction_id   Profit
# customer_id
# 1                           8              11  3018.09
# 2                         129               3  2226.26
# 3                         103               8  3362.81
# 4                         196               2   220.57
# 5                          17               6  2394.94

# %%
data_process.rename(columns = {'transaction_date': 'Recency',
                              'transaction_id': 'Frequency',
                              'Profit': 'MonetaryValue'}, inplace = True)

# %%
data_process.head()
# Out:
#              Recency  Frequency  MonetaryValue
# customer_id
# 1                  8         11        3018.09
# 2                129          3        2226.26
# 3                103          8        3362.81
# 4                196          2         220.57
# 5                 17          6        2394.94

# %%
r_labels = range(4,0,-1)
f_labels = range(1,5)
m_labels = range(1,5)

# %%
r_groups = pd.qcut(data_process['Recency'], q = 4, labels = r_labels)
f_groups = pd.qcut(data_process['Frequency'], q=4, labels = f_labels)
m_groups = pd.qcut(data_process['MonetaryValue'], q=4, labels = m_labels)

# %%
data_process = data_process.assign(R = r_groups.values, F = f_groups.values, M = m_groups.values)

# %%
data_process.head()
# Out:
#              Recency  Frequency  MonetaryValue  R  F  M
# customer_id
# 1                  8         11        3018.09  4  4  3
# 2                129          3        2226.26  1  1  2
# 3                103          8        3362.81  1  4  3
# 4                196          2         220.57  1  1  1
# 5                 17          6        2394.94  4  2  2

# %%
print(data_process['Recency'].max())
print(data_process['Frequency'].max())
print(data_process['MonetaryValue'].max())
# Out:
# 354
# 14
# 11668.949999999999

# %%
data_process['rfm_score'] = data_process[['R','F','M']].sum(axis =1)

# %%
data_process.head()
# Out:
#              Recency  Frequency  MonetaryValue  R  F  M  rfm_score
# customer_id
# 1                  8         11        3018.09  4  4  3       11.0
# 2                129          3        2226.26  1  1  2        4.0
# 3                103          8        3362.81  1  4  3        8.0
# 4                196          2         220.57  1  1  1        3.0
# 5                 17          6        2394.94  4  2  2        8.0

# %%
def rfm_level(df):
    if df['rfm_score'] >= 10:
        return 'Platinum'
    elif ((df['rfm_score'] >= 8) and (df['rfm_score'] < 10)):
        return 'Gold'
    elif ((df['rfm_score'] >= 6) and (df['rfm_score'] < 8)):
        return 'Silver'
    elif ((df['rfm_score'] >= 4) and (df['rfm_score'] < 6)):
        return 'Bronze'
    else:
        return 'Basic'

# %%
data_process['RFM_Level'] = data_process.apply(rfm_level, axis=1)

# %%
data_process.head()
# Out:
#              Recency  Frequency  MonetaryValue  R  F  M  rfm_score RFM_Level
# customer_id
# 1                  8         11        3018.09  4  4  3       11.0  Platinum
# 2                129          3        2226.26  1  1  2        4.0    Bronze
# 3                103          8        3362.81  1  4  3        8.0      Gold
# 4                196          2         220.57  1  1  1        3.0     Basic
# 5                 17          6        2394.94  4  2  2        8.0      Gold

# %%
rfm = data_process.groupby('RFM_Level').agg({'Recency': 'mean',
                                            'Frequency': 'mean',
                                            'MonetaryValue': ['mean', 'count']})
display(rfm)
# Out:
#               Recency Frequency MonetaryValue
#                  mean      mean          mean count
# RFM_Level
# Basic      166.003390  2.606780    937.477017   295
# Bronze      92.845706  3.908297   1787.029440   687
# Gold        39.578027  6.444444   3669.688876   801
# Platinum    23.587342  8.567089   5165.642886   790
# Silver      57.421281  5.011944   2612.117644   921

# %%
Final_Draft = rfm.sort_values([('MonetaryValue', 'mean')], ascending = False)

# %%
Final_Draft
# Out:
#               Recency Frequency MonetaryValue
#                  mean      mean          mean count
# RFM_Level
# Platinum    23.587342  8.567089   5165.642886   790
# Gold        39.578027  6.444444   3669.688876   801
# Silver      57.421281  5.011944   2612.117644   921
# Bronze      92.845706  3.908297   1787.029440   687
# Basic      166.003390  2.606780    937.477017   295

# %%
Final_Draft = Final_Draft.reset_index()
display(Final_Draft)
# Out:
#   RFM_Level     Recency Frequency MonetaryValue
#                    mean      mean          mean count
# 0  Platinum   23.587342  8.567089   5165.642886   790
# 1      Gold   39.578027  6.444444   3669.688876   801
# 2    Silver   57.421281  5.011944   2612.117644   921
# 3    Bronze   92.845706  3.908297   1787.029440   687
# 4     Basic  166.003390  2.606780    937.477017   295

# %%
Final_Draft.rename(columns = {'RFM_Level': 'Customer Type'}, inplace = True)
display(Final_Draft)
# Out:
#   Customer Type     Recency Frequency MonetaryValue
#                        mean      mean          mean count
# 0      Platinum   23.587342  8.567089   5165.642886   790
# 1          Gold   39.578027  6.444444   3669.688876   801
# 2        Silver   57.421281  5.011944   2612.117644   921
# 3        Bronze   92.845706  3.908297   1787.029440   687
# 4         Basic  166.003390  2.606780    937.477017   295

# %%
Final_Draft = Final_Draft.set_index('Customer Type')

# %%
Final_Draft.index
# Out:
# Index(['Platinum', 'Gold', 'Silver', 'Bronze', 'Basic'], dtype='object', name='Customer Type')

# %%
import matplotlib.pyplot as plt
import numpy as np
bars = np.array(range(5))

# %%
plt.xticks(bars,Final_Draft.index)
plt.bar(bars,Final_Draft[('MonetaryValue', 'count')])
# Out:
# <BarContainer object of 5 artists>

# %%
Final_Draft
# Out:
#                   Recency Frequency MonetaryValue
#                      mean      mean          mean count
# Customer Type
# Platinum        23.587342  8.567089   5165.642886   790
# Gold            39.578027  6.444444   3669.688876   801
# Silver          57.421281  5.011944   2612.117644   921
# Bronze          92.845706  3.908297   1787.029440   687
# Basic          166.003390  2.606780    937.477017   295
